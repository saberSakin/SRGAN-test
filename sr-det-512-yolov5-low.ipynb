# %%
# !pip install yolov5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 4.5 MB/s eta 0:00:00
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 97.5 MB/s eta 0:00:00
# ...
# done
# ...

# %%
import shutil
import torch
import os

# %%
# Define your YOLOv5 model
model = 'yolov5x'  # You can use 'yolov5m', 'yolov5l', 'yolov5x' for larger models
pretrained_weights = True  # Set to False if you don't want to use pretrained weights

# %%
if not os.path.exists('yolov5'):
    # !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16522, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 16522 (delta 50), reused 52 (delta 16), pack-reused 16402
# Receiving objects: 100% (16522/16522), 15.18 MiB | 28.48 MiB/s, done.
# Resolving deltas: 100% (11310/11310), done.

# %%
# Change directory to YOLOv5
os.chdir('yolov5')

# %%
# Install dependencies
# !pip install -U -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 91.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 87.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.4 MB/s eta 0:00:00
# ...

# %%
# Download pretrained weights
if pretrained_weights:
    # !bash weights/download_weights.sh
# Out:
# bash: weights/download_weights.sh: No such file or directory

# %%
import yaml

# Define the dataset information
dataset_info = {
    'train': '/kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/train/images',
    'val': '/kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/val/images',
    'test': '/kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/test/images',
    'nc': 11,
    'names': ['airplane', 'boat', 'car', 'cargo ship', 'fighter jet', 'helicopter', 'jet', 'military aircraft', 'propeller plane', 'truck', 'yacht']
}

# Create and save the data.yaml file
data_yaml_path = '/kaggle/working/data.yaml'
with open(data_yaml_path, 'w') as yaml_file:
    yaml.dump(dataset_info, yaml_file, default_flow_style=False)

# %%
# Define your training parameters
data_yaml = '/kaggle/working/data.yaml'
epochs = 100
img_size = 512
batch_size = 8
workers = 4
project_name = 'yolo5run'
name = 'result'

# %%
#disable wandb
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# Train YOLOv5 model
# !python train.py --img-size {img_size} \
                 --batch-size {batch_size} \
                 --epochs {epochs} \
                 --data {data_yaml} \
                 --workers {workers} \
                 --project {project_name} \
                 --name {name}
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-03-26 10:40:04.789823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 10:40:04.789988: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 10:40:04.943457: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# import matplotlib.pyplot as plt

# model_path = '/kaggle/working/yolov5/yolo5run/result/'

# def plot(ls, size):
#     c = 1
#     plt.figure(figsize=(15, 10))
#     for im in ls:
#         plt.subplot(size[0], size[1], c)
#         img = plt.imread(model_path + im)
#         plt.imshow(img)
#         plt.title(im)
#         c += 1
#     plt.show()

# # Visualize images and plots
# # plot(['val_batch0_pred.jpg', 'val_batch2_pred.jpg'], (1, 2))
# plot(['F1_curve.png', 'PR_curve.png'], (1, 2))
# plot([ 'labels.jpg'], (1, 2))
# plot(['results.png'], (1, 1))

# %%
# !python detect.py --weights '/kaggle/working/yolov5/yolo5run/result/weights/best.pt'\
--img 512\
--conf 0.15\
--iou 0.5\
--source /kaggle/input/sr-det-512/SR-DET-512/sat-gen-512x512/test/images\
--exist-ok
# Out:
# detect: weights=['/kaggle/working/yolov5/yolo5run/result/weights/best.pt'], source=/kaggle/input/sr-det-512/SR-DET-512/sat-gen-512x512/test/images, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.15, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.13 torch-2.2.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# image 1/210 /kaggle/input/sr-det-512/SR-DET-512/sat-gen-512x512/test/images/boat103_jpg.rf.0180abb28a3494548af17c6233fe5c8a.jpg: 512x512 2 boats, 3 cars, 8 trucks, 6.3ms
# ...

# %%
# !python val.py --data /kaggle/working/data.yaml --weights /kaggle/working/yolov5/yolo5run/result/weights/best.pt
# Out:
# val: data=/kaggle/working/data.yaml, weights=['/kaggle/working/yolov5/yolo5run/result/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.13 torch-2.2.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/val/labels...
# val: WARNING ⚠️ Cache directory /kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/val is not writeable: [Errno 30] Read-only file system: '/kaggle/input/sr-det-512/SR-DET-512/sat-low-512x512/val/labels.cache.npy'
#                  Class     Images  Instances          P          R      mAP50
# ...
